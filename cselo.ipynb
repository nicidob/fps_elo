# %%
import numpy as np
import pandas as pd
import pickle
import os
import datetime

import dateutil
from dateutil.relativedelta import relativedelta

# %%
tdf = pd.read_html('team_templates.html')
alias_map = {}
clean = lambda x: ''.join(x.split()).lower()
for row in tdf[0].itertuples():
    tn = clean(row[2])
    alias_map[tn] = tn
    for i in range(1,5):
        alias_map[clean(row[i])] = tn
alias_map['pgs.mym'] = 'meetyourmakers'

alias_map['nv'] = 'teamenvy'
alias_map['g2e'] = 'gamers2'
alias_map['g2esports'] = 'gamers2'
alias_map['natusvincere'] = 'navi'
alias_map['verygames'] = 'vg'
alias_map['reasongaming'] = 'reason'
alias_map['gambitesports'] = 'gambit'
alias_map['fazeclan'] = 'faze'
alias_map['opticgaming'] = 'optic'
alias_map['teamenvyus'] = 'teamenvy'
alias_map['ategaming'] = 'ate'
alias_map['cm'] = 'clan-mystik'
alias_map['teamalternate'] = 'alternateattax'
alias_map['teamagent'] = 'agent'
alias_map['k1ckesports'] = 'k1ckesportsclub'
alias_map['ad'] = 'astanadragons'
alias_map['teamdignitas'] = 'dignitas'
alias_map['teamldlc.com'] = 'teamldlc'
alias_map['platinium-esport'] = 'platiniumesport'
alias_map['teamliquid'] = 'tl'
alias_map['swolepatrol'] = 'swole'
alias_map['titanesports'] = 'titan'
alias_map['luminositygaming'] = 'lg'
alias_map['nihilumgaming'] = 'nihilum'
alias_map['keydstars'] = 'keyd'
alias_map['teamkinguin'] = 'kinguin'
alias_map['teamebettle'] = 'ebettle'
alias_map['renegades'] = 'rng'
alias_map['immortals'] = 'imt'
alias_map['teamvitality'] = 'vitality'
alias_map['windigogaming'] = 'windigo'
alias_map['planetkeydynamics'] = 'pdynamics'
alias_map['fm-esports'] = 'fm'
alias_map['vegasquadron'] = 'vega'
alias_map['100thieves'] = '100t'
alias_map['teamldlc.comwhite']= 'ldlcw'
alias_map['teamsolemn']= 'solemn'
alias_map['c0ntactgaming']= 'c0ntact'
alias_map['gen.gesports']= 'gen.g'
alias_map['funplusphoenix'] = 'fpx'
alias_map['chaosec']= 'chaos' 
alias_map['ex-luminosity'] = 'luminosity'
alias_map['cybernetsonline'] = 'cno'
alias_map['spiritofamiga'] = 'soa'
alias_map['b.o.o.t-dream[s]cape'] = 'bootds'
alias_map['pandagaming'] = 'panda.cn'
alias_map['nãotemcomo'] = 'ntc'
alias_map['agoesports']= 'ago'
alias_map['selflessgaming']= 'selfless'
alias_map['swaygaming']= 'sway' 
alias_map['counter-strikearmageddoneurope'] = 'c-sarmaggedon'
alias_map['communityforfreestylers'] = 'c.freestylers'
alias_map['unitedcounterstrikesquad'] = 'unitedcssquad'
alias_map['clananimus']= 'animus'
alias_map['teamxeno']= 'xeno'
alias_map['rs-orange'] = 'rs.orange'
alias_map['w.e.w.'] = 'wew'
alias_map['elitemilitardebrasília'] = 'emb'
alias_map['neverendingviolence']= 'nev' 
alias_map['teamboomtown']= 'boomtown' 
alias_map['team64.amd']= 'team64' 
alias_map['revolutionsportsgaming']= 'tsg' 
alias_map['team64.amd']= 'team64' 
alias_map['teamst']= 'st' 
alias_map['afterlife.se']= 'afterlife' 
alias_map['e-fraggaming']= 'e-frag' 
alias_map['lionsesportsklubb']= 'lions' 
alias_map['wickedesports']= 'wicked' 
alias_map['wickedesports']= 'wicked' 
alias_map['oslf.dk']= 'oslf' 
alias_map['wickedesports']= 'wicked' 
alias_map['teamusa']= 'usa' 
alias_map['lionsesportsklubb']= 'lions' 
alias_map['ckrasgaming']= 'ckras' 
alias_map['teamneverstop']= 'neverstop' 
alias_map['dkhmultigaming']= 'dkh'
alias_map['andthensome']= 'andthensome' 
alias_map['dobry&gaming']= 'loungegaming' 
alias_map['ebettle']= 'ebettle'
alias_map['liquid'] = 'tl'
alias_map['emulate']= 'emulate!' 
alias_map['emulate!']= 'emulate!' 
alias_map['gameplay']= 'gameplay.tv' 
alias_map['gameplay.tv']= 'gameplay.tv' 
alias_map['global.gaming']= 'woosai' 
alias_map['loungegaming']= 'loungegaming' 
alias_map['mirror']= 'andthensome' 
alias_map['singaporesword']= 'singaporesword' 
alias_map['vexedgaming']= 'ebettle' 
alias_map['vitriolicgaming']= 'pgs.mym' 
alias_map['woosai']= 'woosai' 
alias_map['wuhandragon']= 'singaporesword'

# %%
with open('cs_matchesB2.pkl','rb') as fp: #cs_matches
    results = pickle.load(fp)
results['DreamHack/2010/Summer']

# %%
data = []
for k in results:
    basics = [k] + list(results[k][:3]) +[results[k][-2]]
    for m in results[k][3]:
        new_elem = basics + list(m)
        if new_elem[5] == '':
            new_elem[5] = new_elem[3]
        if new_elem[5] == '':
            continue
        t1 = clean(new_elem[6])
        t2 = clean(new_elem[7])
        
        
        new_elem[6] = alias_map.get(t1,t1)
        new_elem[7] = alias_map.get(t2,t2)
        if new_elem[6] == 'teamliquid':
            raise

        data.append(new_elem)

# %%
new_elem,t1

# %%
df = pd.DataFrame(data,columns=['venue','tier','type','vtime','game','mtime','t1','t2','s1','s2','rnds'])
df['mtime'] = df['mtime'].map(lambda x: dateutil.parser.parse(x.replace('??','01')) if type(x) == str else x)
df['mtime'] = pd.to_datetime(df['mtime'],utc=True)

df['t1'] = df['t1'].map(lambda x: x.lower())
df['t2'] = df['t2'].map(lambda x: x.lower())

df = df[df['t1'] != 'bye']
df = df[df['t2'] != 'bye']
#df = df[df.tier.isin(['A','S','B','C'])]
df['type'] = df['type'].map(lambda x: 'Online' if 'Offline' != x else 'Offline')
#df['tier'] = df['tier'].map(lambda x: x if x in set(['A','S','Q']) else 'U')
df['tier'] = df['tier'].map(lambda x: x if x in set(['A','S','B','C']) else 'Q')

df.loc[df.s2 < 0,'s2'] = 0

# golden five hacks
df.loc[(df.t1 == 'again'),'t1'] = 'goldenfive'
df.loc[(df.t2 == 'again'),'t2'] = 'goldenfive'

df.loc[(df.t1 == 'fragexecutors') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2010,month=2,day=16)),'t1'] = 'goldenfive'
df.loc[(df.t2 == 'fragexecutors') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2010,month=2,day=16)),'t2'] = 'goldenfive'


df.loc[(df.t1 == 'escgaming') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2011,month=12,day=7)) & (df['mtime'].dt.tz_convert(None) < datetime.datetime(year=2013,month=10,day=18)),'t1'] = 'goldenfive'
df.loc[(df.t2 == 'escgaming') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2011,month=12,day=7)) & (df['mtime'].dt.tz_convert(None) < datetime.datetime(year=2013,month=10,day=18)),'t2'] = 'goldenfive'


df.loc[df.mtime.map(lambda x: x.year == 2020 and x.month > 6),'mtime'] = df.loc[df.mtime.map(lambda x: x.year == 2020 and x.month > 6),'vtime']
df.loc[(df.t1 == 'meetyourmakers') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2007,month=12,day=17)) & (df['mtime'].dt.tz_convert(None) < datetime.datetime(year=2009,month=3,day=17)),'t1'] = 'goldenfive'
df.loc[(df.t2 == 'meetyourmakers') & (df['mtime'].dt.tz_convert(None) > datetime.datetime(year=2007,month=12,day=17)) & (df['mtime'].dt.tz_convert(None) < datetime.datetime(year=2009,month=3,day=17)),'t2'] = 'goldenfive'
df = df.sort_values('mtime',0,kind='mergesort')

# %%
num_events = dict(df.tier.value_counts())
num_type = dict(df.type.value_counts())
N = df.shape[0]

# %%
score_mul = {  }
for t in num_type:
    for e in num_events:
        score_mul[(e,t)] = (N/num_type[t]) * (N/num_events[e])
        if t == 'Offline':
            score_mul[(e,t)]  *= 3
        
        if e == 'S':
            score_mul[(e,t)]  *= 3
        elif e == 'A':
            pass
        elif e == 'B' or e=='C':
            score_mul[(e,t)]  *= 0.5
        else:
            score_mul[(e,t)]  *= 0.1
score_mul

# %%
#xn = np.linspace(0,500)
#plt.plot(xn,sigmoid((xn-cMean)*cVar))
#print(blend,amount)

# %%
import numpy as np
import datetime

def sigmoid2(x):
    "Numerically-stable sigmoid function."
    if x >= 0:
        z = 10**(-x/400.0)
        return 1 / (1 + z)
    else:
        z = 10**(x/400.0)
        return z / (1 + z)
def sigmoid(x):
    #if type(x) != np.array:
    #    return sigmoid2(x)

    z1 = 10**(-x/400.0)
    z2 = 10**(x/400.0)

    return np.select([x>=0,x<0],[1/(1+z1),z2/(1+z2)])
scale_magic = np.sqrt(initial_v)
def benchmark_func(x):

    ratings = {}
    prev_update = {}
    x = (np.array(x).flatten()) * scale_magic

    x = abs(x)
    per_ratings = {('Q','Online'):x[0],
                   ('C','Online'):x[1],
                   ('B','Online'):x[2],
                   ('A','Online'):x[3],
                   ('S','Online'):x[4],
                   ('Q','Offline'):x[5],
                   ('C','Offline'):x[6],
                   ('B','Offline'):x[7],
                   ('A','Offline'):x[8],
                   ('S','Offline'):x[9]}
    per_ratings_const = {('Q','Online'):x[10],
                   ('C','Online'):x[11],
                   ('B','Online'):x[12],
                   ('A','Online'):x[13],
                   ('S','Online'):x[14],
                   ('Q','Offline'):x[15],
                   ('C','Offline'):x[16],
                   ('B','Offline'):x[17],
                   ('A','Offline'):x[18],
                   ('S','Offline'):x[19]}
    power = x[20]
    power2 = x[21]
    cMean = 100*x[22]
    cVar =  x[23]
    blend= np.exp(-x[24])
    amount= np.exp(-x[25])
    score = 0.0
    correct = 0
    total_g = 0
    for row in df.itertuples():
        t1 = row[7] + '_' + row[5]
        t2 = row[8] + '_' + row[5]
        cTime = row[6].replace(tzinfo=None)
        time1 = prev_update.get(t1,cTime)
        time2 = prev_update.get(t2,cTime)
        
        total = row[9]+row[10]
        diff = abs(row[9]-row[10])
        if total < 1 or diff <1:
            prev_update[t1] = cTime
            prev_update[t2] = cTime
            continue
        diff /= total

        r1 = ratings.get(t1,1500)
        r2 = ratings.get(t2,1500)
        
        td1 = float((cTime - time1).days)
        to1500_1 = float(sigmoid((td1-cMean)*cVar))
        r1 = (to1500_1)*1500 + (1-to1500_1)*r1
        
        td2 = float((cTime - time2).days)
        to1500_2 = float(sigmoid((td2-cMean)*cVar))
        r2 = (to1500_2)*1500 + (1-to1500_2)*r2
        
        rdiff = abs(r1-r2)
        p1 = float(sigmoid(r1-r2))
        p2 = 1 - p1
        K = ((diff**power) * per_ratings[row[2:4]]) + per_ratings_const[row[2:4]]
        K = K*blend + amount*rdiff*(1-blend)

    
        sMul = score_mul[row[2:4]] * max(0.1,(r1+r2)/3000.0)
        
        if row[2] in ['A','S']:
            correct += int((row[9] > row[10]) == ( r1 > r2)) *sMul
            total_g += sMul
        
        if row[9] > row[10]:
            E = p2
            ratings[t1] = r1 + K * E**power2
            ratings[t2] = r2 - K * E**power2
            
            score += -np.log(max(p1,1e-3)) * sMul
        else:
            E = p1
            ratings[t1] = r1 - K * E**power2
            ratings[t2] = r2 + K * E**power2
            
            score += -np.log(max(p2,1e-3)) * sMul
        prev_update[t1] = cTime
        prev_update[t2] = cTime
    return score#/(max(1e-3,(correct)/total_g-0.5))**0.1#,ratings
initial_v2 = np.array([  0.36898797,   9.18643443, 119.75259179,  57.97762704,
       145.12612498, 215.13104508,   1.99478431, 192.44794057,
        13.86448357,   7.17607518, 141.78574903,  19.26903679,
         8.70247483,   1.73506721,  34.6487012 ,   1.20132298,
         1.44099928,  40.05764688])
initial_v = np.ones(26).astype(np.float32)*2

initial_v = np.array([   0.36898797, 0.36898797,0.36898797,
                      9.18643443, 119.75259179,  57.97762704,57.97762704,57.97762704,
       145.12612498, 215.13104508,   1.99478431,1.99478431,1.99478431, 192.44794057,
        13.86448357,   7.17607518, 7.17607518, 7.17607518, 141.78574903,  19.26903679,
         8.70247483,   1.73506721,  34.6487012 ,   1.20132298,
         1.44099928,  40.05764688])

initial_v = np.array([ 18.25072838,  74.59076659,  95.96793023, 114.93916893,  11.30159452,
  64.72672347,   1.90024806,  63.24657822,  43.70996726,  79.62341069,
  10.29926388,  14.5887735,   71.14937516,  63.98827863,  80.96915655,
  83.31334684,  33.7840958,   92.0514089,  135.24950821,  25.94777709,
   5.01919907,   2.07565228,  34.60000695 , 19.7854935,    0.8508004,
  14.9930185, ])

# two dais
initial_v = [  0.000001 ,    0.00002568 ,  0.00001593, 132.66496462, 386.4914683,
  74.74613172,  95.83931716,   0.00005563, 134.98681673, 306.2403323,
   0.00000039,   0.00001299,  14.9428415,  274.32772789,  86.78671798,
   0.00047612,   0.00009709,   0.00015441, 136.9136137,    0.00009243,
  13.46715752,   1.69961637,  17.54813621, 162.45646977,   1.82940522,
 102.31210837]


scale_magic = np.sqrt(initial_v)
#initial_v = np.ones(18).astype(np.float32)*2 #2979704
s= benchmark_func(initial_v/scale_magic)
s

# %%
#2194176.4888980826
#2213824
# full acc: 6.0875
# 1/4 acc: 3906712

# %%
import cma
from cma import optimization_tools
es = cma.CMAEvolutionStrategy(initial_v/scale_magic, 1, {'tolx':1e-2,'tolfun':1e-2})
#es.optimize(benchmark_func,n_jobs=0)

# %%
es.result_pretty()  #

# %%
np.set_printoptions(suppress=True)

abs(es.best.x)*scale_magic

# %%
#print(benchmark_func(np.array([ 5, 25 , 2,  10, 31, 45, 1])))
#print(benchmark_func(np.array([ 2, 22 , 0.2,  9, 26, 42, 0.5])))
print(benchmark_func(initial_v/scale_magic))
print(benchmark_func(es.best.x))

# %%
from collections import defaultdict
per_ratings = {('Q','Online'):initial_v[0],
               ('C','Online'):initial_v[1],
               ('B','Online'):initial_v[2],
               ('A','Online'):initial_v[3],
               ('S','Online'):initial_v[4],
               ('Q','Offline'):initial_v[5],
               ('C','Offline'):initial_v[6],
               ('B','Offline'):initial_v[7],
               ('A','Offline'):initial_v[8],
               ('S','Offline'):initial_v[9]}
per_ratings_const = {('Q','Online'):initial_v[10],
               ('C','Online'):initial_v[11],
               ('B','Online'):initial_v[12],
               ('A','Online'):initial_v[13],
               ('S','Online'):initial_v[14],
               ('Q','Offline'):initial_v[15],
               ('C','Offline'):initial_v[16],
               ('B','Offline'):initial_v[17],
               ('A','Offline'):initial_v[18],
               ('S','Offline'):initial_v[19]}
power = initial_v[20]
power2 = initial_v[21]
cMean = 100*initial_v[22]
cVar =  initial_v[23]
blend= np.exp(-initial_v[24])
amount= np.exp(-initial_v[25])
score = 0.0
tmpd = []
tmpd2 = []
correct = 0
total_g = 0

rt = defaultdict(list)


ratings = {}
prev_update = {}

score = 0.0

for row in df.itertuples():
    t1 = row[7] + '_' + row[5]
    t2 = row[8] + '_' + row[5]
    cTime = row[6].replace(tzinfo=None)
    time1 = prev_update.get(t1,cTime)
    time2 = prev_update.get(t2,cTime)

    total = row[9]+row[10]
    diff = abs(row[9]-row[10])
    if total < 1 or diff <1:
        prev_update[t1] = cTime
        prev_update[t2] = cTime
        continue
    diff /= total

    r1 = ratings.get(t1,1500)
    r2 = ratings.get(t2,1500)

    td1 = float((cTime - time1).days)
    to1500_1 = float(sigmoid2((td1-cMean)*cVar))
    r1 = (to1500_1)*1500 + (1-to1500_1)*r1

    td2 = float((cTime - time2).days)
    to1500_2 = float(sigmoid2((td2-cMean)*cVar))
    r2 = (to1500_2)*1500 + (1-to1500_2)*r2

    rdiff = abs(r1-r2)
    p1 = float(sigmoid(r1-r2))
    p2 = 1 - p1
    K = ((diff**power) * per_ratings[row[2:4]]) + per_ratings_const[row[2:4]]
    K = K*blend + amount*rdiff*(1-blend)


    sMul = score_mul[row[2:4]] * max(0.1,(r1+r2)/3000.0)

    if row[2] in ['A','S']:
        correct += int((row[9] > row[10]) == ( r1 > r2)) *sMul
        total_g += sMul

    if row[9] > row[10]:
        E = p2
        ratings[t1] = r1 + K * E**power2
        ratings[t2] = r2 - K * E**power2

        score += -np.log(max(p1,1e-3)) * sMul
    else:
        E = p1
        ratings[t1] = r1 - K * E**power2
        ratings[t2] = r2 + K * E**power2

        score += -np.log(max(p2,1e-3)) * sMul
    prev_update[t1] = cTime
    prev_update[t2] = cTime

    rt[t1].append((row[6],ratings[t1]))
    rt[t2].append((row[6],ratings[t2]))
score,100*correct/total_g,score/max(1e-3,(correct)/total_g-0.5)**0.25

# %%
rt['godsent_csgo'] #65.6185791669261 #2507147

# %%
max(np.array(rt['skgaming_csgo'])[:,1])

# %%
top_teams = sorted([(max(np.array(v)[:,1]),k) for k,v in rt.items() if len(v) > 0],reverse=True)
top_teams

# %%
import matplotlib.pyplot as plt
import datetime
plt.style.use('fivethirtyeight')
plt.figure(dpi=120)
for i in range(5):
    tm = top_teams[i][1]
    team_plot = np.array(rt[tm])
    
    argmin = np.argmax(team_plot[:,1])
    peak = team_plot[argmin]
    print(tm,peak[0])
    plt.plot(team_plot[:,0],team_plot[:,1],label=tm,lw=2,alpha=0.5)
    
    plt.scatter([peak[0]],[peak[1]],c=plt.gca().lines[-1].get_color(),s=100)
plt.legend()
plt.xlim(datetime.datetime(year=2004,month=1,day=1),datetime.datetime(year=2020,month=6,day=1))
plt.xlabel('year')
plt.ylabel('Elo')
plt.title('Top 5 CS teams of all time')

# %%
sorted([(v,k) for k,v in ratings.items()],reverse=True)

# %%
import matplotlib.pyplot as plt
import datetime
plt.style.use('fivethirtyeight')
plt.figure(dpi=120,figsize=(8,6))
for tm in ['navi_cs16','skgaming_cs16','ninjasinpyjamas_cs16','fnatic_cs16','astralis_csgo','goldenfive_cs16']:
    team_plot = np.array(rt[tm])
    
    argmin = np.argmax(team_plot[:,1])
    peak = team_plot[argmin]
    print(tm,peak[0])
    plt.plot(team_plot[:,0],team_plot[:,1],label=tm,lw=2,alpha=0.5)
    
    plt.scatter([peak[0]],[peak[1]],c=plt.gca().lines[-1].get_color(),s=100)
plt.legend(loc=3)
plt.xlim(datetime.datetime(year=1995,month=1,day=1),datetime.datetime(year=2020,month=6,day=1))
plt.xlabel('year')
plt.ylabel('Elo')
plt.title('A few more top teams')
plt.tight_layout()

# %%
def get_top_at(time,team_data,timedel = datetime.timedelta(weeks=30)):
    td = timedel
    rt = team_data
    time = tm
    team_idx = {k: abs(np.array([_[0].replace(tzinfo=None) for _ in v])-tm) for k,v in rt.items() if len(v) > 0}
    team_idx = {k:np.argmin(v) for k,v in team_idx.items() if sum(v < td) > 1}
    top_teams_year = sorted([(round(np.nan_to_num(rt[k][i][1])),k) for k,i in team_idx.items()],reverse=True)
    return top_teams_year

# %%
tm = datetime.datetime(month=6,year=2020,day=12)
top_teams_year = get_top_at(tm,rt,datetime.timedelta(weeks=3))
print(tm,top_teams_year[:16])

# %%
for yr in range(2020,2020):
    tm = datetime.datetime(month=1,year=yr+1,day=1)
    top_teams_year = get_top_at(tm,rt)
    print(tm,top_teams_year[:5])

# %%
import math

max_year = defaultdict(dict)
for k in rt:
    yrs = set([int(_[0].year) for _ in rt[k]])
    yrs = list(sorted(yrs))
    tm_d = {}
    for y in yrs:
        max_year[y][k] = max([(_[1],_[0]) for _ in rt[k] if _[0].year == y and not math.isnan(_[1]) ])


alt_year = defaultdict(dict)
for k in rt:
    yrs = set([int(_[0].year) for _ in rt[k]])
    yrs = list(sorted(yrs))
    tm_d = {}
    for y in yrs:
        vals = [_[1]**2 for _ in rt[k] if _[0].year == y and not math.isnan(_[1]) ]
        vals = sorted(vals)#[3:]
        if len(vals) > 3:
            alt_year[y][k] = np.sqrt(np.mean(vals))

# %%
for yr in range(2000,2021):
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if 'sweden' not in k and 'ladies' not in k],reverse=True)
    print('* **' +str(yr) + '**',end='\t')#,top_teams_year[:5])
    i=0
    for s,n in top_teams_year[:6]:
        i+=1
        entk = ', ' if i!=6 else '\n'
        print('{} ({})'.format(n.split('_')[0],int(s)),end=entk)

# %%
 
max_best_ever = []
for yr, res in max_year.items():
    for tm, pelo in res.items():
        max_best_ever.append( (int(round(pelo[0])),pelo[1].strftime("%Y-%m-%d"),str(yr) +'__' + tm))
sorted(max_best_ever,reverse=True)[:50]

# %%
alt_best_ever = []
for yr, res in alt_year.items():
    for tm, pelo in res.items():
        alt_best_ever.append( (pelo,str(yr) +'__' + tm))
sorted(alt_best_ever,reverse=True)[:50]

# %%
alias_map

# %%
from colorthief import ColorThief

color_dict = {}
for fn in os.listdir('.'):
    nm, ext = os.path.splitext(fn)
    if ext == '.png':
        color_dict[nm] = [np.array(_)/255.0 for _ in ColorThief(fn).get_palette(2)]
for k,v in color_dict.items():
    idx = 0
    if k == 'mousesports':
        idx = 1
    elif k == 'goldenfive' or k=='fragexecutors':
        idx = 2
    elif k == 'teamenvy':
        idx = 2
    elif k == 'vg':
        idx = 2
    elif k == 'faze':
        idx = 1
    elif k == 'virtus.pro':
        idx = 1
    color_dict[k] = v[idx]
    if k == 'navi':
        color_dict[k] *= 0.8
    elif k == 'mtw':
        color_dict[k] *= 0.8
    elif k == 'fragexecutors':
        color_dict[k] *= 0.6

#color_dict['teamsolomid'] = color_dict['astralis']

# %%
top_teams

# %%
def get_top_year_elo(tm,yr,rt):
    return max([(_[1],_[0]) for _ in rt[tm] if _[0].year == yr])

# %%
tp_tm_merged = {}
for r,tm in top_teams:
    gm = tm.split('_')[-1]
    tm = '_'.join(tm.split('_')[:-1])
    if tm == 'mtw':
         r += 7
    tp_tm_merged[tm] = max((r,gm),tp_tm_merged.get(tm,(0,gm)))

top_tm = sorted([(v[0],k,v[1]) for k,v in tp_tm_merged.items()],reverse=True)

# %%
top_tm[0][2]

# %%
import matplotlib.pyplot as plt
import datetime
plt.style.use('fivethirtyeight')
plt.figure(dpi=120,figsize=(12,8))
plt.subplot(2,1,1)

for i in range(6):
    tog = top_tm[i][1] + '_' + top_tm[i][2]
    team_plot = np.array(rt[tog])

    tm =  top_tm[i][1]
    
    argmin = np.argmax(team_plot[:,1])
    peak = team_plot[argmin]
    color = color_dict[tm]
    print(tm,peak[0])
    plt.plot(team_plot[:,0],team_plot[:,1],label=tm,lw=4,alpha=0.7,c=color)
    
    team_plot = np.array(rt[tm + "_csgo"])
    plt.plot(team_plot[:,0],team_plot[:,1],lw=4,alpha=0.7,c=color)

    
    plt.scatter([peak[0]],[peak[1]],c=plt.gca().lines[-1].get_color(),s=150)
    if tm == 'skgaming':
        y,x = get_top_year_elo(tog,2004,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
    if tm == 'fnatic':
        y,x = get_top_year_elo(tm + "_cs16",2010,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
        y,x = get_top_year_elo(tm + '_csgo',2015,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
plt.legend(loc="lower left", ncol=6)
#it's safer to use linestyle='none' and marker='none' that setting the color to white
#should be invisible whatever is the background
plt.xlim(datetime.datetime(year=2003,month=6,day=1),datetime.datetime(year=2020,month=6,day=1))
plt.xlim(datetime.datetime(year=2003,month=6,day=1),datetime.datetime(year=2020,month=6,day=1))
plt.ylim(top=1950,bottom= 1600)

plt.xlabel('year')
plt.ylabel('Elo')
plt.title('Top CS teams of all time (by peak Elo) #1')

import matplotlib.pyplot as plt
import datetime
plt.style.use('fivethirtyeight')
plt.subplot(2,1,2)
tmp_teams = []
for i in range(6,12):
    tog = top_tm[i][1] + '_' + top_tm[i][2]
    team_plot = np.array(rt[tog])

    tm =  top_tm[i][1]
    
    color = color_dict[tm]

    argmin = np.argmax(team_plot[:,1])
    peak = team_plot[argmin]
    print(tm,peak[0])
    tm = 'tsm' if 'teamsolomid' in tm else tm
    plt.plot(team_plot[:,0],team_plot[:,1],label=tm if tm not in tmp_teams else '',lw=4,alpha=0.7,c=color)
    tmp_teams.append(tm)
    plt.scatter([peak[0]],[peak[1]],c=plt.gca().lines[-1].get_color(),s=150)
    
    if 'csgo' in top_tm[i][2]:
        team_plot = np.array(rt[tm + "_cs16"])
        if team_plot.shape[0] > 0:
            plt.plot(team_plot[:,0],team_plot[:,1],lw=4,alpha=0.7,c=color)
    
    if 'cs16' in top_tm[i][2]:
        team_plot = np.array(rt[tm + "_csgo"])
        if team_plot.shape[0] > 0:
            plt.plot(team_plot[:,0],team_plot[:,1],lw=4,alpha=0.7,c=color)
    if tm == 'ninjasinpyjamas':
        y,x = get_top_year_elo(tm + "_csgo",2013,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
        y,x = get_top_year_elo(tm + "_csgo",2014,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)

    if tm == 'mousesports':
        y,x = get_top_year_elo(tm+"_cs16",2008,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
    if tm == 'navi':
        y,x = get_top_year_elo(tm + "_csgo",2020,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
        y,x = get_top_year_elo(tm + "_csgo",2016,rt)
        plt.scatter([x],[y],c=plt.gca().lines[-1].get_color(),s=150)
plt.legend(loc="upper left", ncol=6)
plt.xlim(datetime.datetime(year=2003,month=6,day=1),datetime.datetime(year=2020,month=6,day=8))
plt.ylim(top=1950,bottom= 1600)
plt.xlabel('year')
plt.ylabel('Elo')
plt.title('Top CS teams of all time (by peak Elo) #2')
plt.tight_layout()

# %%
nm

# %%
from matplotlib.ticker import MaxNLocator
import matplotlib.dates as mdates
from collections import OrderedDict
import matplotlib.pyplot as plt

# %%
TP = 'astralis'
plt.figure(figsize=(8,4))
valid_years = set([2017,2018,2019,2020])

tm2 = TP + '_csgo'
ratings = np.array([_ for _ in rt[tm2] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[TP])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden'],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == tm2:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2)
# Set the locator
locator = mdates.YearLocator()
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')


X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('Astralis vs. the other top 10 teams')

# %%
TP = 'ninjasinpyjamas'
plt.figure(figsize=(8,4))
valid_years = list(range(2012,2015))

tm2 = TP + '_csgo'
ratings = np.array([_ for _ in rt[tm2] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[TP])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and  '_csgo' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == tm2:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2)
# Set the locator
locator = mdates.YearLocator()
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')


X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('NiP vs. the other top 10 teams')

# %%
TP = 'skgaming_cs16'
plt.figure(figsize=(8,4))
valid_years = set(range(2002,2006))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict['skgaming'])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden'],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2)
#plt.xlim(datetime.datetime(year=2017,month=1,day=1),datetime.datetime(year=2020,month=6,day=8))
# Set the locator
locator = mdates.YearLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')


X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('SK vs. the other top 10 teams')

# %%
TP = 'fnatic_csgo'
plt.figure(figsize=(8,4))
valid_years = set(range(2012,2017))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if '_csgo' in k and k != 'sweden'],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2)
#plt.xlim(datetime.datetime(year=2017,month=1,day=1),datetime.datetime(year=2020,month=6,day=8))
# Set the locator
locator = mdates.YearLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')


X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('fnatic vs. the other top 10 teams')

# %%
plt.figure(figsize=(8,4))

TP = 'ninjasinpyjamas_csgo'
valid_years = set(range(2012,2015))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='NiP')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_csgo' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        print(tm)
        if tm == TP or tm in ['vg']:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr ])
        if len(ratings) < 1:
            continue
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)


TP = 'fnatic_csgo'
valid_years = set(range(2015,2017))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years or (_[0].year == 2014 and _[0].month >10) ])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label=TP.split('_')[0])

valid_years = set(range(2015,2017))

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_csgo' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP or tm == 'teamenvy' or tm == 'navi':
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)

TP = 'teamsolomid_csgo'
valid_years = set(range(2015,2016))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='tsm')

        
TP = 'astralis_csgo'
valid_years = set(range(2018,2018))

tm = TP
#ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
#plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='FaZe')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_csgo' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        #if tm == 'faze': continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)

TP = 'astralis_csgo'
valid_years = set(range(2017,2021))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label=TP.split('_')[0])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_csgo' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        if yr == 2019 and tm == 'tl': continue
        #if tm == 'faze': continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)
        
TP = 'tl_csgo'
valid_years = set(range(2019,2020))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='liquid')


TP = 'gamers2_csgo'
valid_years = set(range(2013,2021))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
#plt.plot(ratings[:,0],ratings[:,1],c='k',label=TP.split('_')[0])

plt.legend(loc="lower center", ncol=6)

# Set the locator
locator = mdates.YearLocator()
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('Top Teams in CS:GO\n (other top 10 teams in gray)')

# %%
df.shape

# %%
plt.figure(figsize=(12,4))

TP = 'ninjasinpyjamas_cs16'
valid_years = set(range(2001,2002))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='NiP')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)
        
TP = 'mtw_cs16'
valid_years = set(range(2002,2003))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='mTw')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)
        

TP = 'skgaming_cs16'
valid_years = set(range(2003,2007))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])
valid_years = set(range(2003,2006))

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        if tm == 'ninjasinpyjamas_cs16' and yr == 2006:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)

TP = 'ninjasinpyjamas_cs16'
valid_years = set(range(2006,2007))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP or tm == 'skgaming_cs16':
            print('skip ',tm)
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)
        
        
TP = 'fnatic_cs16'
valid_years = set(range(2007,2009))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='fnatic')
valid_years = set(range(2007,2011))
for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP or tm in set(['mtw_cs16','skgaming_cs16']):
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        if ratings.shape[0] < 1:
            continue
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)

TP = 'skgaming_cs16'
valid_years = set(range(2008,2009))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])

TP = 'mtw_cs16'
valid_years = set(range(2009,2010))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])


TP = 'mousesports_cs16'
valid_years = set(range(2008,2009))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='mouz')



TP = 'skgaming_cs16'
valid_years = set(range(2011,2013))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='SK')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if k != 'sweden' and '_cs16' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        #if tm == 'ninjasinpyjamas_cs16': continue
        #if tm == 'navi_cs16': continue
        #if tm == 'goldenfive_cs16': continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2,lw=2)


TP = 'navi_cs16'
valid_years = set(range(2011,2012))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]],label='NAVI')

TP = 'fnatic_cs16'
valid_years = set(range(2010,2011))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])

TP = 'goldenfive_cs16'
valid_years = set(range(2011,2012))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c='#00a86b',label='GoldenFive')



TP = 'fnatic_cs16'
valid_years = set(range(2012,2013))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c=color_dict[tm.split('_')[0]])

if False:
    valid_list = []
    valid_lines = []
    for line, label in zip(handles, labels):
        if label in valid_list:
            continue
        valid_list.append(label)
        valid_lines.append(line)
plt.legend(loc="lower center", ncol=7)

# Set the locator
locator = mdates.YearLocator()
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%Y')

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.ylabel('Elo')
plt.title('Top Teams in CS1.6\n (other top 10 teams in gray)')

# %%
tm,yr

# %%
[_ for _ in top_teams if '_css' in _[1]]

# %%
TP = 'vg_css'
valid_years = set(range(2005,2014))

tm = TP
ratings = np.array([_ for _ in rt[tm] if _[0].year in valid_years])
plt.plot(ratings[:,0],ratings[:,1],c='b',label='VG')

for yr in valid_years:
    top_teams_year = sorted([(v,k) for k,v in alt_year[yr].items() if '_css' in k],reverse=True)
    for ratingT, tm in top_teams_year[:10]:
        if tm == TP:
            continue
        ratings = np.array([_ for _ in rt[tm] if _[0].year == yr])
        plt.plot(ratings[:,0],ratings[:,1],c='k',alpha=0.2)
plt.legend()

# %%
[_ for _ in top_teams if '_cso' in _[1]]

# %%
plt.plot(xn,sigmoid((xn-cMean)*cVar))

# %%
ratings
